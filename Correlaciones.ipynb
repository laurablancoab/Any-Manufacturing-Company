# %%
# Importar bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar datos
Purchases_Final = pd.read_csv('/content/PurchasesFINAL.csv')

# %%
# Cargar datos
Sales_Final = pd.read_csv('/content/SalesFINAL.csv')

# %%
# Cargar datos
Invoice_Purchases = pd.read_csv('/content/InvoicePurchases.csv')

# %%
# Cargar datos
Purchase_Prices = pd.read_csv('/content/2017PurchasePricesFinal.csv')

# %%
# Cargar datos
Begin_Final = pd.read_csv('/content/BegInvFinal.csv')

# %%
# Cargar datos
End_Inv= pd.read_csv('/content/EndInvFinal.csv')

# %%
sns.heatmap(Purchases_Final.corr(numeric_only=True),annot=True,cmap='coolwarm',mask=Purchases_Final.corr(numeric_only=True)<0)
plt.show()

# %%
sns.heatmap(Invoice_Purchases.corr(numeric_only=True),annot=True,cmap='coolwarm',mask=Invoice_Purchases.corr(numeric_only=True)<0)
plt.show()

# %%
sns.heatmap(Sales_Final.corr(numeric_only=True),annot=True,cmap='coolwarm',mask=Sales_Final.corr(numeric_only=True)<0)
plt.show()

# %%
sns.heatmap(Purchase_Prices.corr(numeric_only=True),annot=True,cmap='coolwarm',mask=Purchase_Prices.corr(numeric_only=True)<0)
plt.show()

# %%
sns.heatmap(Begin_Final.corr(numeric_only=True),annot=True,cmap='coolwarm',mask=Begin_Final.corr(numeric_only=True)<0)
plt.show()

# %%
sns.heatmap(End_Inv.corr(numeric_only=True),annot=True,cmap='coolwarm',mask=End_Inv.corr(numeric_only=True)<0)
plt.show()
